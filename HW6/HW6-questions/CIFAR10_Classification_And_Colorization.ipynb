# %% [markdown]
# # CIFAR10 Classification
#
# In this part of the assignment we want to do an image classification task using PyTorch on CIFAR10 dataset.

# %% [markdown]
# ## Import Libraries
#
# Import needed libraries

# %% [markdown]
# ## Device
#
# Set device to work with (GPU or CPU)

# %%
# Out:
# device(type='cuda')

# %% [markdown]
# ## Transforms & Dataset & Dataloader
#
# Here, you should download and load the dataset with the desire transforms. After that, you should split train dataset to train and validation sets. Finally, define the dataloaders for `train`, `validation` and `test`

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to dataset/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting dataset/cifar-10-python.tar.gz to dataset
# Files already downloaded and verified

# %% [markdown]
# ## Visualization
#
# Visualize 5 random images from each class in different columns
#
# - **Hint**:  You can use `plt.subplots` for visualization

# %% [markdown]
# ## Model
#
# Define your model here from scratch (You are not allowed to use the existing models in pytorch)
#
# **NOTICE:** The model that you will have defined outputs a vector containing 10 numbers (for each class). Define a "feature space" that is a vector of size *N* (where *N > 10*) right before the last layer (You can then have a last layer like `nn.Linear(N, 10)`). See the image below to get a better understanding. We will use this later (we want to access the feature space of a sample when the sample is given to the model). The model tries to learn a representation of the samples in this feature space and we will see how good it could do this in later sections.
#
# ![Feature Space In Neural Network](https://i.postimg.cc/28Qjcn9D/feature-space-vis.png)
#
# - **Hint I**: Our goal is to get accuracy above *90%* on testset. Our suggestion is to implement ResNet (ResNet18 could be a viable choice)
#   - You can learn the network's structure and implementation online (Youtube, ...) and then implmenet it yourself and make changes to enhance it's performance on our task **(YOU SHOULD NOT COPY THE CODE!!! OTHERWISE, YOU'LL BE PENALIZED!!!)**
#
# - **Hint II**: When defining your model, pay attension to the **NOTICE** part in the above. It's also better to read the "Exploring the feature space" section beforehand.

# %% [markdown]
# ## Train

# %% [markdown]
# ### Model instantiation
#
# Create an instance of your model and move it to `device`

# %% [markdown]
# ### Criterion & Optimizater
#
# Define `criterion` and `optimizer` (Or `scheduler`)

# %% [markdown]
# ### Train loop
#
# Train your model
#
# Tasks:
# - [ ] Things that are needed to be printed in each epoch:
#   - Number of epoch
#   - Train loss
#   - Train accuracy
#   - Validation loss
#   - Validation accuracy
# - [ ] save train/validation loss and accuracy (of each epoch) in an array for later usage

# %%
# Out:
# [Epoch 0]	[18:28:13]	Train Loss: 1.6003	Train Accuracy: 0.43	Validation Loss: 1.2983		Validation Accuracy: 0.53
# [Epoch 1]	[18:32:45]	Train Loss: 1.0466	Train Accuracy: 0.63	Validation Loss: 1.4428		Validation Accuracy: 0.55
# [Epoch 2]	[18:37:17]	Train Loss: 0.8723	Train Accuracy: 0.70	Validation Loss: 0.8079		Validation Accuracy: 0.72
# [Epoch 3]	[18:41:47]	Train Loss: 0.6823	Train Accuracy: 0.77	Validation Loss: 0.6540		Validation Accuracy: 0.78
# [Epoch 4]	[18:46:18]	Train Loss: 0.5842	Train Accuracy: 0.80	Validation Loss: 0.6186		Validation Accuracy: 0.79
# [Epoch 5]	[18:50:49]	Train Loss: 0.5155	Train Accuracy: 0.82	Validation Loss: 0.5647		Validation Accuracy: 0.81
# [Epoch 6]	[18:55:21]	Train Loss: 0.4588	Train Accuracy: 0.84	Validation Loss: 0.5397		Validation Accuracy: 0.82
# [Epoch 7]	[18:59:53]	Train Loss: 0.4197	Train Accuracy: 0.86	Validation Loss: 0.5129		Validation Accuracy: 0.82
# [Epoch 8]	[19:04:25]	Train Loss: 0.3852	Train Accuracy: 0.87	Validation Loss: 0.5822		Validation Accuracy: 0.81
# [Epoch 9]	[19:08:57]	Train Loss: 0.3568	Train Accuracy: 0.88	Validation Loss: 0.4509		Validation Accuracy: 0.85
# [Epoch 10]	[19:13:27]	Train Loss: 0.3261	Train Accuracy: 0.89	Validation Loss: 0.3948		Validation Accuracy: 0.86
# [Epoch 11]	[19:17:58]	Train Loss: 0.3110	Train Accuracy: 0.89	Validation Loss: 0.3835		Validation Accuracy: 0.86
# [Epoch 12]	[19:22:29]	Train Loss: 0.2955	Train Accuracy: 0.90	Validation Loss: 0.4179		Validation Accuracy: 0.86
# [Epoch 13]	[19:27:02]	Train Loss: 0.2751	Train Accuracy: 0.90	Validation Loss: 0.3714		Validation Accuracy: 0.88
# [Epoch 14]	[19:31:34]	Train Loss: 0.2600	Train Accuracy: 0.91	Validation Loss: 0.3745		Validation Accuracy: 0.88
# [Epoch 15]	[19:36:06]	Train Loss: 0.2463	Train Accuracy: 0.91	Validation Loss: 0.3350		Validation Accuracy: 0.89
# [Epoch 16]	[19:40:37]	Train Loss: 0.2313	Train Accuracy: 0.92	Validation Loss: 0.4100		Validation Accuracy: 0.86
# [Epoch 17]	[19:45:08]	Train Loss: 0.2206	Train Accuracy: 0.92	Validation Loss: 0.3006		Validation Accuracy: 0.90
# [Epoch 18]	[19:49:38]	Train Loss: 0.2064	Train Accuracy: 0.93	Validation Loss: 0.3527		Validation Accuracy: 0.88
# [Epoch 19]	[19:54:11]	Train Loss: 0.2032	Train Accuracy: 0.93	Validation Loss: 0.3931		Validation Accuracy: 0.87
# [Epoch 20]	[19:58:43]	Train Loss: 0.1934	Train Accuracy: 0.93	Validation Loss: 0.3678		Validation Accuracy: 0.89
# [Epoch 21]	[20:03:14]	Train Loss: 0.1898	Train Accuracy: 0.93	Validation Loss: 0.3252		Validation Accuracy: 0.89
# [Epoch 22]	[20:07:45]	Train Loss: 0.1765	Train Accuracy: 0.94	Validation Loss: 0.3153		Validation Accuracy: 0.90
# [Epoch 23]	[20:12:15]	Train Loss: 0.1646	Train Accuracy: 0.94	Validation Loss: 0.2978		Validation Accuracy: 0.90
# [Epoch 24]	[20:16:45]	Train Loss: 0.1546	Train Accuracy: 0.94	Validation Loss: 0.2998		Validation Accuracy: 0.90
# [Epoch 25]	[20:21:17]	Train Loss: 0.0794	Train Accuracy: 0.97	Validation Loss: 0.2089		Validation Accuracy: 0.93
# [Epoch 26]	[20:25:49]	Train Loss: 0.0552	Train Accuracy: 0.98	Validation Loss: 0.2086		Validation Accuracy: 0.93
# [Epoch 27]	[20:30:21]	Train Loss: 0.0454	Train Accuracy: 0.99	Validation Loss: 0.2072		Validation Accuracy: 0.93
# [Epoch 28]	[20:34:53]	Train Loss: 0.0377	Train Accuracy: 0.99	Validation Loss: 0.2092		Validation Accuracy: 0.94
# [Epoch 29]	[20:39:23]	Train Loss: 0.0351	Train Accuracy: 0.99	Validation Loss: 0.2153		Validation Accuracy: 0.93
# [Epoch 30]	[20:43:54]	Train Loss: 0.0309	Train Accuracy: 0.99	Validation Loss: 0.2095		Validation Accuracy: 0.94
# [Epoch 31]	[20:48:24]	Train Loss: 0.0278	Train Accuracy: 0.99	Validation Loss: 0.2184		Validation Accuracy: 0.94
# [Epoch 32]	[20:52:57]	Train Loss: 0.0253	Train Accuracy: 0.99	Validation Loss: 0.2159		Validation Accuracy: 0.94
# [Epoch 33]	[20:57:29]	Train Loss: 0.0232	Train Accuracy: 0.99	Validation Loss: 0.2090		Validation Accuracy: 0.94
# [Epoch 34]	[21:02:01]	Train Loss: 0.0214	Train Accuracy: 0.99	Validation Loss: 0.2141		Validation Accuracy: 0.94

# %% [markdown]
# ### Visualize Loss and Accuracy plot
#
# Using the arrays that you have (from task 2 in the above section), visualize two plots: Accuracy plot (train and validation together) and Loss plot (train and validation together)

# %% [markdown]
# ## Evaluation
#
# Test your trained model (using the Test Dataloader that you have). Our goal is to reach an accuracy above `90%`

# %%
# Out:
# 0.9365

# %% [markdown]
# ## Visualize incorrectly predicted samples from testset
#
# Visualize *24* random images from testset that are incorrectly predicted by the model

# %% [markdown]
# ## Exploring the feature space

# %% [markdown]
# ### Calculate the feature space for all training samples
#
# You have trained and evaluated your model. Now, for each sample in the trainset, calculate it's "feature space" discussed in the model section. The result of this section should be a tensor of size `(50000, N)` saved in a variable (for later usage)
#
# - **Hint 1:** define a tensor with dimension `(50000, N)` where *50000* is the size of the trainset and *N* is the dimension of the feature space
#
# - **Hint 2:** Pay attension to the `shuffle` attribute of your train dataloader (If needed)

# %% [markdown]
# ### K Nearest Neighbor in feature space
#
# You already have calculated the feature spaces for trainset ($S$) in the previous section
#
# 1. Get 5 random samples from testset which are correctly predicted by the model.
# 2. for each sample, calculate it's "feature space" ($X$)
# 3. for each sample, calculate it's *5* nearest neighbors in "feature space" in the trainset (by comparing $X$ to each row in $S$) and visualize them
#
# **Note:** Your visualization should be something like the below picture
#
# **Hint:** For finding the nearest neighbors in the feature space you can use `torch.linalg.norm` and `torch.topk`

# %% [markdown]
# ### TSNE

# %% [markdown]
# 1. Sample $M$ ($2000$ would be enought) random samples from the trainset feature space (calculated in the above sections)
# 2. Now you a vector of size `(M, N)` where $N$ is the dimension of the feature space
# 3. Using TSNE reduce $N$ to $2$ (Now you have a vector of size `(M, 2)`)
# 4. Print the shape of the output
#
# **Hint:** You can use `sklearn.manifold.TSNE`

# %%
# Out:
# (2000, 2)

# %% [markdown]
# Visualize the points in a 2D plane (Set color of each point based on it's class)
#
# **Notice:** Your visualization should be something like the below image
#
# **Hint:** Use `plt.scatter(x, y, c=labels)`

# %% [markdown]
# # CIFAR10 Colorization
#
# In this part of the assignment, we want to do an image colorization task using PyTorch on CIFAR10 dataset. We want to train a model that colors  a black-and-white image.

# %% [markdown]
# ## Import Libraries
#
# Import needed libraries

# %% [markdown]
# ## Custom Dataset
#
# Define a custom dataset class by extensing `torch.utils.data.Dataset`
#
# **Notice:** your dataset should output two things: black-and-white image and the RGB image
#
# **Hint:** You don't have to reinvent the wheel. Your class should just be a wrapper for CIFAR10 dataset

# %% [markdown]
# ## Transforms & Dataset & Dataloader
#
# **Notice:** Use your defined custom dataset class for defining the datasets

# %%
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Dataset Visualization
#
# Visualize your dataset (black-and-white image along with the RGB image) by sampling from your trainset

# %% [markdown]
# ## Model
#
# Define your model here (Input: black-and-white image, Output: RGB image)
#
# **Hint:** You can implement an autoencoder that does the colorization task for you. UNet could be a viable option

# %% [markdown]
# ## Train
#
# Train your model
#
# Tasks:
# - [ ] Things that are needed to be printed in each epoch:
#   - Number of epoch
#   - Train loss
#   - Validation loss
# - [ ] save train/validation loss (of each epoch) in an array for later usage

# %%
# Out:
# [Epoch 0]	[00:51:54]	Train Loss: 0.0112	Validation Loss: 0.0063
# [Epoch 1]	[00:52:50]	Train Loss: 0.0063	Validation Loss: 0.0062
# [Epoch 2]	[00:53:46]	Train Loss: 0.0060	Validation Loss: 0.0056
# [Epoch 3]	[00:54:42]	Train Loss: 0.0058	Validation Loss: 0.0085
# [Epoch 4]	[00:55:39]	Train Loss: 0.0057	Validation Loss: 0.0054
# [Epoch 5]	[00:56:35]	Train Loss: 0.0057	Validation Loss: 0.0066
# [Epoch 6]	[00:57:31]	Train Loss: 0.0056	Validation Loss: 0.0055
# [Epoch 7]	[00:58:26]	Train Loss: 0.0055	Validation Loss: 0.0053
# [Epoch 8]	[00:59:22]	Train Loss: 0.0055	Validation Loss: 0.0062
# [Epoch 9]	[01:00:18]	Train Loss: 0.0055	Validation Loss: 0.0055
# [Epoch 10]	[01:01:14]	Train Loss: 0.0053	Validation Loss: 0.0056
# [Epoch 11]	[01:02:10]	Train Loss: 0.0053	Validation Loss: 0.0053
# [Epoch 12]	[01:03:04]	Train Loss: 0.0053	Validation Loss: 0.0056
# [Epoch 13]	[01:03:57]	Train Loss: 0.0051	Validation Loss: 0.0069
# [Epoch 14]	[01:04:51]	Train Loss: 0.0053	Validation Loss: 0.0057
# [Epoch 15]	[01:05:45]	Train Loss: 0.0051	Validation Loss: 0.0066
# [Epoch 16]	[01:06:39]	Train Loss: 0.0057	Validation Loss: 0.0060
# [Epoch 17]	[01:07:34]	Train Loss: 0.0054	Validation Loss: 0.0058
# [Epoch 18]	[01:08:28]	Train Loss: 0.0051	Validation Loss: 0.0050
# [Epoch 19]	[01:09:22]	Train Loss: 0.0050	Validation Loss: 0.0053
# [Epoch 20]	[01:10:16]	Train Loss: 0.0049	Validation Loss: 0.0050
# [Epoch 21]	[01:11:11]	Train Loss: 0.0048	Validation Loss: 0.0051
# [Epoch 22]	[01:12:05]	Train Loss: 0.0047	Validation Loss: 0.0053
# [Epoch 23]	[01:12:59]	Train Loss: 0.0045	Validation Loss: 0.0052
# [Epoch 24]	[01:13:53]	Train Loss: 0.0044	Validation Loss: 0.0056
# [Epoch 25]	[01:14:47]	Train Loss: 0.0043	Validation Loss: 0.0057
# [Epoch 26]	[01:15:42]	Train Loss: 0.0040	Validation Loss: 0.0053
# [Epoch 27]	[01:16:36]	Train Loss: 0.0038	Validation Loss: 0.0055
# [Epoch 28]	[01:17:30]	Train Loss: 0.0037	Validation Loss: 0.0055
# [Epoch 29]	[01:18:24]	Train Loss: 0.0034	Validation Loss: 0.0058
# [Epoch 30]	[01:19:18]	Train Loss: 0.0033	Validation Loss: 0.0070
# [Epoch 31]	[01:20:12]	Train Loss: 0.0047	Validation Loss: 0.0053
# [Epoch 32]	[01:21:07]	Train Loss: 0.0036	Validation Loss: 0.0054
# [Epoch 33]	[01:22:02]	Train Loss: 0.0033	Validation Loss: 0.0056
# [Epoch 34]	[01:22:58]	Train Loss: 0.0030	Validation Loss: 0.0057
# [Epoch 35]	[01:23:54]	Train Loss: 0.0029	Validation Loss: 0.0054
# [Epoch 36]	[01:24:50]	Train Loss: 0.0028	Validation Loss: 0.0055
# [Epoch 37]	[01:25:45]	Train Loss: 0.0028	Validation Loss: 0.0056
# [Epoch 38]	[01:26:41]	Train Loss: 0.0027	Validation Loss: 0.0058
# [Epoch 39]	[01:27:37]	Train Loss: 0.0027	Validation Loss: 0.0062
# [Epoch 40]	[01:28:33]	Train Loss: 0.0026	Validation Loss: 0.0064
# [Epoch 41]	[01:29:29]	Train Loss: 0.0025	Validation Loss: 0.0056
# [Epoch 42]	[01:30:25]	Train Loss: 0.0024	Validation Loss: 0.0065
# [Epoch 43]	[01:31:21]	Train Loss: 0.0024	Validation Loss: 0.0056
# [Epoch 44]	[01:32:16]	Train Loss: 0.0024	Validation Loss: 0.0056
# [Epoch 45]	[01:33:12]	Train Loss: 0.0023	Validation Loss: 0.0068
# [Epoch 46]	[01:34:08]	Train Loss: 0.0023	Validation Loss: 0.0055
# [Epoch 47]	[01:35:04]	Train Loss: 0.0022	Validation Loss: 0.0058
# [Epoch 48]	[01:36:00]	Train Loss: 0.0021	Validation Loss: 0.0055
# [Epoch 49]	[01:36:55]	Train Loss: 0.0021	Validation Loss: 0.0056
# [Epoch 50]	[01:37:52]	Train Loss: 0.0018	Validation Loss: 0.0053
# [Epoch 51]	[01:38:48]	Train Loss: 0.0017	Validation Loss: 0.0054
# [Epoch 52]	[01:39:43]	Train Loss: 0.0017	Validation Loss: 0.0053
# [Epoch 53]	[01:40:35]	Train Loss: 0.0016	Validation Loss: 0.0054
# [Epoch 54]	[01:41:28]	Train Loss: 0.0016	Validation Loss: 0.0054
# [Epoch 55]	[01:42:22]	Train Loss: 0.0016	Validation Loss: 0.0053
# [Epoch 56]	[01:43:17]	Train Loss: 0.0016	Validation Loss: 0.0054
# [Epoch 57]	[01:44:11]	Train Loss: 0.0016	Validation Loss: 0.0054
# [Epoch 58]	[01:45:05]	Train Loss: 0.0015	Validation Loss: 0.0054
# [Epoch 59]	[01:46:00]	Train Loss: 0.0015	Validation Loss: 0.0055
# [Epoch 60]	[01:46:56]	Train Loss: 0.0015	Validation Loss: 0.0054
# [Epoch 61]	[01:47:52]	Train Loss: 0.0015	Validation Loss: 0.0054
# [Epoch 62]	[01:48:47]	Train Loss: 0.0015	Validation Loss: 0.0054
# [Epoch 63]	[01:49:43]	Train Loss: 0.0015	Validation Loss: 0.0054
# [Epoch 64]	[01:50:38]	Train Loss: 0.0015	Validation Loss: 0.0054
# [Epoch 65]	[01:51:33]	Train Loss: 0.0015	Validation Loss: 0.0054
# [Epoch 66]	[01:52:29]	Train Loss: 0.0015	Validation Loss: 0.0055
# [Epoch 67]	[01:53:24]	Train Loss: 0.0014	Validation Loss: 0.0055
# [Epoch 68]	[01:54:20]	Train Loss: 0.0014	Validation Loss: 0.0055
# [Epoch 69]	[01:55:16]	Train Loss: 0.0014	Validation Loss: 0.0055
# [Epoch 70]	[01:56:11]	Train Loss: 0.0014	Validation Loss: 0.0054
# [Epoch 71]	[01:57:07]	Train Loss: 0.0014	Validation Loss: 0.0055
# [Epoch 72]	[01:58:02]	Train Loss: 0.0014	Validation Loss: 0.0055
# [Epoch 73]	[01:58:56]	Train Loss: 0.0014	Validation Loss: 0.0055
# [Epoch 74]	[01:59:52]	Train Loss: 0.0014	Validation Loss: 0.0054
# [Epoch 75]	[02:00:48]	Train Loss: 0.0014	Validation Loss: 0.0055
# [Epoch 76]	[02:01:44]	Train Loss: 0.0014	Validation Loss: 0.0055
# [Epoch 77]	[02:02:40]	Train Loss: 0.0014	Validation Loss: 0.0055
# [Epoch 78]	[02:03:34]	Train Loss: 0.0013	Validation Loss: 0.0056
# [Epoch 79]	[02:04:26]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 80]	[02:05:20]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 81]	[02:06:14]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 82]	[02:07:08]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 83]	[02:08:03]	Train Loss: 0.0013	Validation Loss: 0.0056
# [Epoch 84]	[02:08:57]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 85]	[02:09:51]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 86]	[02:10:45]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 87]	[02:11:39]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 88]	[02:12:33]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 89]	[02:13:28]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 90]	[02:14:22]	Train Loss: 0.0013	Validation Loss: 0.0055
# [Epoch 91]	[02:15:16]	Train Loss: 0.0013	Validation Loss: 0.0056
# [Epoch 92]	[02:16:10]	Train Loss: 0.0013	Validation Loss: 0.0056
# [Epoch 93]	[02:17:04]	Train Loss: 0.0012	Validation Loss: 0.0055
# [Epoch 94]	[02:17:59]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 95]	[02:18:53]	Train Loss: 0.0012	Validation Loss: 0.0055
# [Epoch 96]	[02:19:47]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 97]	[02:20:41]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 98]	[02:21:35]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 99]	[02:22:30]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 100]	[02:23:24]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 101]	[02:24:20]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 102]	[02:25:15]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 103]	[02:26:11]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 104]	[02:27:07]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 105]	[02:28:02]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 106]	[02:28:58]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 107]	[02:29:53]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 108]	[02:30:50]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 109]	[02:31:45]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 110]	[02:32:41]	Train Loss: 0.0012	Validation Loss: 0.0057
# [Epoch 111]	[02:33:37]	Train Loss: 0.0012	Validation Loss: 0.0055
# [Epoch 112]	[02:34:33]	Train Loss: 0.0012	Validation Loss: 0.0056
# [Epoch 113]	[02:35:29]	Train Loss: 0.0012	Validation Loss: 0.0057
# [Epoch 114]	[02:36:26]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 115]	[02:37:22]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 116]	[02:38:17]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 117]	[02:39:12]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 118]	[02:40:08]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 119]	[02:41:03]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 120]	[02:41:56]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 121]	[02:42:50]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 122]	[02:43:44]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 123]	[02:44:38]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 124]	[02:45:33]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 125]	[02:46:27]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 126]	[02:47:21]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 127]	[02:48:17]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 128]	[02:49:13]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 129]	[02:50:08]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 130]	[02:51:04]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 131]	[02:52:00]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 132]	[02:52:55]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 133]	[02:53:51]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 134]	[02:54:47]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 135]	[02:55:43]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 136]	[02:56:38]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 137]	[02:57:33]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 138]	[02:58:30]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 139]	[02:59:26]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 140]	[03:00:21]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 141]	[03:01:17]	Train Loss: 0.0011	Validation Loss: 0.0057
# [Epoch 142]	[03:02:13]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 143]	[03:03:08]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 144]	[03:04:04]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 145]	[03:04:59]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 146]	[03:05:51]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 147]	[03:06:45]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 148]	[03:07:40]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 149]	[03:08:34]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 150]	[03:09:28]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 151]	[03:10:22]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 152]	[03:11:16]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 153]	[03:12:11]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 154]	[03:13:05]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 155]	[03:13:59]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 156]	[03:14:53]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 157]	[03:15:47]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 158]	[03:16:41]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 159]	[03:17:36]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 160]	[03:18:30]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 161]	[03:19:24]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 162]	[03:20:18]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 163]	[03:21:13]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 164]	[03:22:07]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 165]	[03:23:01]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 166]	[03:23:55]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 167]	[03:24:50]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 168]	[03:25:47]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 169]	[03:26:42]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 170]	[03:27:38]	Train Loss: 0.0011	Validation Loss: 0.0057
# [Epoch 171]	[03:28:34]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 172]	[03:29:29]	Train Loss: 0.0011	Validation Loss: 0.0057
# [Epoch 173]	[03:30:25]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 174]	[03:31:21]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 175]	[03:32:16]	Train Loss: 0.0011	Validation Loss: 0.0057
# [Epoch 176]	[03:33:12]	Train Loss: 0.0011	Validation Loss: 0.0057
# [Epoch 177]	[03:34:08]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 178]	[03:35:04]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 179]	[03:36:00]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 180]	[03:36:56]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 181]	[03:37:52]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 182]	[03:38:48]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 183]	[03:39:44]	Train Loss: 0.0011	Validation Loss: 0.0057
# [Epoch 184]	[03:40:40]	Train Loss: 0.0011	Validation Loss: 0.0057
# [Epoch 185]	[03:41:35]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 186]	[03:42:30]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 187]	[03:43:22]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 188]	[03:44:16]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 189]	[03:45:10]	Train Loss: 0.0011	Validation Loss: 0.0057
# [Epoch 190]	[03:46:05]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 191]	[03:46:59]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 192]	[03:47:53]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 193]	[03:48:49]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 194]	[03:49:45]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 195]	[03:50:40]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 196]	[03:51:36]	Train Loss: 0.0011	Validation Loss: 0.0057
# [Epoch 197]	[03:52:32]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 198]	[03:53:28]	Train Loss: 0.0011	Validation Loss: 0.0056
# [Epoch 199]	[03:54:23]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 200]	[03:55:19]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 201]	[03:56:15]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 202]	[03:57:11]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 203]	[03:58:07]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 204]	[03:59:02]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 205]	[03:59:58]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 206]	[04:00:53]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 207]	[04:01:49]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 208]	[04:02:46]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 209]	[04:03:41]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 210]	[04:04:36]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 211]	[04:05:31]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 212]	[04:06:23]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 213]	[04:07:17]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 214]	[04:08:11]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 215]	[04:09:05]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 216]	[04:09:59]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 217]	[04:10:53]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 218]	[04:11:48]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 219]	[04:12:42]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 220]	[04:13:36]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 221]	[04:14:30]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 222]	[04:15:24]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 223]	[04:16:19]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 224]	[04:17:13]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 225]	[04:18:07]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 226]	[04:19:01]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 227]	[04:19:55]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 228]	[04:20:50]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 229]	[04:21:44]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 230]	[04:22:38]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 231]	[04:23:32]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 232]	[04:24:26]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 233]	[04:25:21]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 234]	[04:26:16]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 235]	[04:27:12]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 236]	[04:28:08]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 237]	[04:29:04]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 238]	[04:30:00]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 239]	[04:30:55]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 240]	[04:31:52]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 241]	[04:32:48]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 242]	[04:33:44]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 243]	[04:34:40]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 244]	[04:35:36]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 245]	[04:36:32]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 246]	[04:37:28]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 247]	[04:38:25]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 248]	[04:39:21]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 249]	[04:40:16]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 250]	[04:41:12]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 251]	[04:42:07]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 252]	[04:43:04]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 253]	[04:43:57]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 254]	[04:44:51]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 255]	[04:45:45]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 256]	[04:46:39]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 257]	[04:47:34]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 258]	[04:48:28]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 259]	[04:49:22]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 260]	[04:50:18]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 261]	[04:51:13]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 262]	[04:52:09]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 263]	[04:53:05]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 264]	[04:54:00]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 265]	[04:54:55]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 266]	[04:55:51]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 267]	[04:56:47]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 268]	[04:57:43]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 269]	[04:58:39]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 270]	[04:59:34]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 271]	[05:00:30]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 272]	[05:01:26]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 273]	[05:02:21]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 274]	[05:03:17]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 275]	[05:04:13]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 276]	[05:05:09]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 277]	[05:06:05]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 278]	[05:07:01]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 279]	[05:07:53]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 280]	[05:08:46]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 281]	[05:09:41]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 282]	[05:10:35]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 283]	[05:11:29]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 284]	[05:12:23]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 285]	[05:13:17]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 286]	[05:14:12]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 287]	[05:15:06]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 288]	[05:16:00]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 289]	[05:16:54]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 290]	[05:17:48]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 291]	[05:18:43]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 292]	[05:19:37]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 293]	[05:20:31]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 294]	[05:21:25]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 295]	[05:22:19]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 296]	[05:23:14]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 297]	[05:24:08]	Train Loss: 0.0010	Validation Loss: 0.0057
# [Epoch 298]	[05:25:02]	Train Loss: 0.0010	Validation Loss: 0.0056
# [Epoch 299]	[05:25:56]	Train Loss: 0.0010	Validation Loss: 0.0056

# %% [markdown]
# ### Visualize Loss plot
#
# Using the arrays that you have (from task 2 in the above section), visualize the loss plot (train and validation together)

# %% [markdown]
# ## Evaluation
#
# 1. Sample 36 random samples from testset (your own dataset class)
# 2. Give each of the 36 samples to your trained model and get the outputs
# 3. Visualize `input` (black-and-white image), `output` (output of the model with the given black-and-white input image) and `ground truth` (the actual RGB image)
